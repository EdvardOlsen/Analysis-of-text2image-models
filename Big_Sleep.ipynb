# %%
# !pip install big-sleep --upgrade
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting big-sleep
#   Downloading big_sleep-0.9.1-py3-none-any.whl (1.4 MB)
#      |████████████████████████████████| 1.4 MB 13.0 MB/s
# Requirement already satisfied: torch>=1.7.1 in /usr/local/lib/python3.7/dist-packages (from big-sleep) (1.11.0+cu113)
# Requirement already satisfied: regex in /usr/local/lib/python3.7/dist-packages (from big-sleep) (2019.12.20)
# Collecting einops>=0.3
#   Downloading einops-0.4.1-py3-none-any.whl (28 kB)
# Collecting fire
#   Downloading fire-0.4.0.tar.gz (87 kB)
#      |████████████████████████████████| 87 kB 2.8 MB/s
# Collecting pytorch-pretrained-biggan
#   Downloading pytorch_pretrained_biggan-0.1.1-py3-none-any.whl (27 kB)
# Requirement already satisfied: torchvision>=0.8.2 in /usr/local/lib/python3.7/dist-packages (from big-sleep) (0.12.0+cu113)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.7/dist-packages (from big-sleep) (4.64.0)
# Collecting ftfy
#   Downloading ftfy-6.1.1-py3-none-any.whl (53 kB)
#      |████████████████████████████████| 53 kB 702 kB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from torch>=1.7.1->big-sleep) (4.2.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.8.2->big-sleep) (2.23.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.8.2->big-sleep) (1.21.6)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.7/dist-packages (from torchvision>=0.8.2->big-sleep) (7.1.2)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from fire->big-sleep) (1.15.0)
# Requirement already satisfied: termcolor in /usr/local/lib/python3.7/dist-packages (from fire->big-sleep) (1.1.0)
# Requirement already satisfied: wcwidth>=0.2.5 in /usr/local/lib/python3.7/dist-packages (from ftfy->big-sleep) (0.2.5)
# Collecting boto3
#   Downloading boto3-1.23.7-py3-none-any.whl (132 kB)
#      |████████████████████████████████| 132 kB 38.1 MB/s
# Collecting botocore<1.27.0,>=1.26.7
#   Downloading botocore-1.26.7-py3-none-any.whl (8.8 MB)
#      |████████████████████████████████| 8.8 MB 32.0 MB/s
# Collecting jmespath<2.0.0,>=0.7.1
#   Downloading jmespath-1.0.0-py3-none-any.whl (23 kB)
# Collecting s3transfer<0.6.0,>=0.5.0
#   Downloading s3transfer-0.5.2-py3-none-any.whl (79 kB)
#      |████████████████████████████████| 79 kB 7.8 MB/s
# Collecting urllib3<1.27,>=1.25.4
#   Downloading urllib3-1.26.9-py2.py3-none-any.whl (138 kB)
#      |████████████████████████████████| 138 kB 48.1 MB/s
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /usr/local/lib/python3.7/dist-packages (from botocore<1.27.0,>=1.26.7->boto3->pytorch-pretrained-biggan->big-sleep) (2.8.2)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.8.2->big-sleep) (2022.5.18.1)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.8.2->big-sleep) (2.10)
#   Downloading urllib3-1.25.11-py2.py3-none-any.whl (127 kB)
#      |████████████████████████████████| 127 kB 48.7 MB/s
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.7/dist-packages (from requests->torchvision>=0.8.2->big-sleep) (3.0.4)
# Building wheels for collected packages: fire
#   Building wheel for fire (setup.py) ... done
#   Created wheel for fire: filename=fire-0.4.0-py2.py3-none-any.whl size=115942 sha256=88566c57f5f16134c1c1bb1d0a227b339ff3d95008b7cd4ca9f8a263d0d18b03
#   Stored in directory: /root/.cache/pip/wheels/8a/67/fb/2e8a12fa16661b9d5af1f654bd199366799740a85c64981226
# Successfully built fire
# Installing collected packages: urllib3, jmespath, botocore, s3transfer, boto3, pytorch-pretrained-biggan, ftfy, fire, einops, big-sleep
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 1.24.3
#     Uninstalling urllib3-1.24.3:
#       Successfully uninstalled urllib3-1.24.3
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# datascience 0.10.6 requires folium==0.2.1, but you have folium 0.8.3 which is incompatible.
# Successfully installed big-sleep-0.9.1 boto3-1.23.7 botocore-1.26.7 einops-0.4.1 fire-0.4.0 ftfy-6.1.1 jmespath-1.0.0 pytorch-pretrained-biggan-0.1.1 s3transfer-0.5.2 urllib3-1.25.11

# %%
from tqdm.notebook import trange
from IPython.display import Image, display

from big_sleep import Imagine

TEXT = '3 apples and 2 bananas on a silver plate' #@param {type:"string"}
SAVE_EVERY = 100 #@param {type:"number"}
SAVE_PROGRESS = True #@param {type:"boolean"}
LEARNING_RATE = 5e-2 #@param {type:"number"}
ITERATIONS = 1050 #@param {type:"number"}
SEED = 0 #@param {type: "number"}

model = Imagine(
    text = TEXT,
    save_every = SAVE_EVERY,
    lr = LEARNING_RATE,
    iterations = ITERATIONS,
    save_progress = SAVE_PROGRESS,
    seed = SEED
)

for epoch in trange(20, desc = 'epochs'):
    for i in trange(1000, desc = 'iteration'):
        model.train_step(epoch, i)

        if i == 0 or i % model.save_every != 0:
            continue

        filename = TEXT.replace(' ', '_')
        image = Image(f'./{filename}.png')
        display(image)
# Out:
# setting seed of 0
# you can override this with --seed argument in the command line, or --random for a randomly chosen one
# epochs:   0%|          | 0/20 [00:00<?, ?it/s]
# iteration:   0%|          | 0/1000 [00:00<?, ?it/s]
